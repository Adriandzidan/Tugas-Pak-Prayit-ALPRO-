# %% [markdown]
# <a href="https://colab.research.google.com/github/Adriandzidan/Tugas-Pak-Prayit-ALPRO-/blob/main/Jobsheet09.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **HASIL PRAKTIKUM**

# %% [markdown]
# 1. **Praktikum 01 – Menggunakan Modul math**

# %%
import math

angka = 16
hasil1 = math.sqrt(angka)
hasil2 = math.pow(2,5)
print("Akar Kuadrat dari", angka, "=", hasil1)
print("2 pangkat 5 =", hasil2)
# Out:
# Akar Kuadrat dari 16 = 4.0
# 2 pangkat 5 = 32.0

# %% [markdown]
# 2. **Praktikum 02 – Menggunakan from … import …**

# %%
from math import sqrt

angka = 25
hasil = sqrt(angka)
print("Akar kuadrat dari", angka, "=", hasil)
# Out:
# Akar kuadrat dari 25 = 5.0

# %% [markdown]
# 3. **Praktikum 03 – Memberi Alias Modul**

# %%
import numpy as np

data = np.array([1, 2, 3])
print("Isi array=", data)
# Out:
# Isi array= [1 2 3]

# %% [markdown]
# 4. **Praktikum 04 – Eksplorasi math, random, dan sys**

# %%
import math
import random
import sys

hasil1 = math.sqrt(81)
hasil2 = random.randint(1, 10)
versi = sys.version

print("Akar kuadrat 81 =", hasil1)
print("Angka acak 1–10 =", hasil2)
print("Versi Python =", versi)
# Out:
# Akar kuadrat 81 = 9.0
# Angka acak 1–10 = 1
# Versi Python = 3.12.12 (main, Oct 10 2025, 08:52:57) [GCC 11.4.0]

# %% [markdown]
# 5. **Praktikum 05 – Membuat Modul Sendiri**

# %%
# %%writefile modulku.py
def halo(nama):
  print(F"Halo, {nama}! selamat belajar phyton di polines.")
# Out:
# Writing modulku.py

# %%
# %%writefile praktikum09_modul_sendiri.py
import modulku

modulku.halo("Mahasiswa Polines")
# Out:
# Writing praktikum09_modul_sendiri.py

# %% [markdown]
# 6. **Praktikum 06 – Instalasi Modul dengan pip**

# %%
# !pip install requests
import requests

response = requests.get("https://www.polines.ac.id")
print("Status code:", response.status_code)
# Out:
# ...
# Status code: 403

# %% [markdown]
# # **PENUGASAN**

# %% [markdown]
# 1. **Eksperimen dengan Modul math**

# %%
import math

def luas_lingkaran(r):
    return math.pi * (r ** 2)

print("Luas lingkaran dengan jari jari 7 =", luas_lingkaran(7))
print("Luas lingkaran dengan jari-jari 10 =", luas_lingkaran(10))
# Out:
# Luas lingkaran dengan jari jari 7 = 153.93804002589985
# Luas lingkaran dengan jari-jari 10 = 314.1592653589793

# %% [markdown]
# 2. **Eksperimen dengan Modul random**

# %%
import random

print("5 angka acak (1-100):")
for _ in range(5):
    print(random.randint(1, 100))
# Out:
# 5 angka acak (1-100):
# 66
# 60
# 88
# 14
# 50

# %% [markdown]
# 3. **Modul sys**

# %%
import sys

print("--informasi sistem --")
print("Platform:", sys.platform)
print("Version:", sys.version)
# Out:
# --informasi sistem --
# Platform: linux
# Version: 3.12.12 (main, Oct 10 2025, 08:52:57) [GCC 11.4.0]

# %% [markdown]
# 4.	**Modul Buatan Sendiri**

# %%
# %%writefile konversi.py
def c_to_f(angka):
  f = angka * 1.8 + 32
  print(f"Konversi dari {angka} Celcius ke Fahrenheit adalah: °{f}")

def f_to_c(angka):
  c = (angka - 32 ) / 1.8
  print(f"Konversi dari {angka} Fahrenheit ke Celcius adalah: °{c}")
# Out:
# Writing konversi.py

# %%
import konversi

print("----- Konversi -----")
print("1. Celcius ke Fahrenheit")
print("2. Fahrenheit ke Celcius")
print("--------------------")
print()
pilih = int(input("Masukkan angka: "))


if pilih == 1:
  angka =int(input("Masukkan angka yang ingin anda konversi menjadi Fahrenheit: "))
  konversi.c_to_f(angka)
else:
  angka =int(input("Masukkan angka yang ingin anda konversi menjadi Celcius: "))
  konversi.f_to_c(angka)
# Out:
# ----- Konversi -----
# 1. Celcius ke Fahrenheit
# 2. Fahrenheit ke Celcius
# --------------------
#
# Masukkan angka: 15
# Masukkan angka yang ingin anda konversi menjadi Celcius: 15
# Konversi dari 15 Fahrenheit ke Celcius adalah: °-9.444444444444445

# %% [markdown]
# 5. **instalasi library pihak ketiga**

# %%
import pandas as pd

data = {
    "NIM": ["43325001", "43325022", "43325003"],
    "Nama": ["Mamat", "tanto", "dumbo"],
    "Prodi": ["Teknik Elektro", "Teknik Material", "Teknik Mesin"]
}

df = pd.DataFrame(data)

print(df)
# Out:
#         NIM   Nama            Prodi
# 0  43325001  Mamat   Teknik Elektro
# 1  43325022  tanto  Teknik Material
# 2  43325003  dumbo     Teknik Mesin

# %% [markdown]
# **6. Studi Kasus Mini**

# %%
# %%writefile laporan.py
def ringkasan_skor(skor, total):
    print("\n=== Ringkasan Skor ===")
    print(f"Skor akhir Anda: {skor} dari {total} soal")
    if skor == total:
        print("Luar biasa! Semua jawaban benar.")
    elif skor > total // 2:
        print("Bagus, Anda sudah cukup baik.")
    else:
        print("Ayo belajar lagi, ya!")

        print("SEMANGAT!!!")
# Out:
# Overwriting laporan.py

# %%
import random
import laporan
import importlib

importlib.reload(laporan)

def kuis_penjumlahan(jumlah_soal=5):
    skor = 0
    for i in range(jumlah_soal):
        a = random.randint(1, 20)
        b = random.randint(1, 20)
        jawaban = int(input(f"Soal {i+1}: Berapa {a} + {b}? "))
        if jawaban == a + b:
            print("Benar!")
            skor += 1
        else:
            print(f"Salah")
    return skor, jumlah_soal

def main():
    print("=== Kuis Penjumlahan Acak ===")
    skor, total = kuis_penjumlahan()
    laporan.ringkasan_skor(skor, total)

main()
# Out:
# === Kuis Penjumlahan Acak ===
# Soal 1: Berapa 13 + 9? 1
# Salah
# Soal 2: Berapa 5 + 19? 1
# Salah
# Soal 3: Berapa 8 + 20? 1
# Salah
# Soal 4: Berapa 1 + 14? 1
# Salah
# Soal 5: Berapa 20 + 14? 1
# Salah
#
# === Ringkasan Skor ===
# Skor akhir Anda: 0 dari 5 soal
# Ayo belajar lagi, ya!
# SEMANGAT!!!
